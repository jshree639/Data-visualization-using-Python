# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
wpop=pd.read_csv('C:\\Users\\Saran\\sample practice\\world.csv')

# %%
wpop.head()
# Out:
#    population_in_2023  population_in_2022       city     country  \
# 0            37194105            37274002      Tokyo       Japan
# 1            32941309            32065760      Delhi       India
# 2            29210808            28516903   Shanghai       China
# 3            23209616            22478117      Dhaka  Bangladesh
# 4            22619736            22429799  Sao Paulo      Brazil
#
#    population_growthRate
# 0                -0.0021
# 1                 0.0273
# 2                 0.0243
# 3                 0.0325
# 4                 0.0085

# %%
wpop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   population_in_2023     778 non-null    int64
#  1   population_in_2022     778 non-null    int64
#  2   city                   778 non-null    object
#  3   country                778 non-null    object
#  4   population_growthRate  778 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 30.5+ KB

# %%
wpop.describe()
# Out:
#        population_in_2023  population_in_2022  population_growthRate
# count        7.780000e+02        7.780000e+02             778.000000
# mean         2.658927e+06        2.607826e+06               0.020758
# std          3.700349e+06        3.638665e+06               0.013135
# min          7.500970e+05        7.231140e+05              -0.034800
# 25%          9.921812e+05        9.657890e+05               0.012625
# 50%          1.381252e+06        1.362342e+06               0.019950
# 75%          2.607130e+06        2.548158e+06               0.028675
# max          3.719410e+07        3.727400e+07               0.061100

# %%
import seaborn as sns
import matplotlib as pyplot

# %%
sns.barplot(x=wpop['population_in_2022'],y=wpop['population_in_2023'], color='g')
# Out:
# <Axes: xlabel='population_in_2022', ylabel='population_in_2023'>

# %%
sns.histplot(x=wpop['population_in_2022'],y=wpop['population_in_2023'])
# Out:
# <Axes: xlabel='population_in_2022', ylabel='population_in_2023'>

# %%
sns.jointplot(x=wpop['population_in_2022'],y=wpop['population_in_2023'],kind="kde")

# %%
sns.pairplot(wpop[['population_in_2022','population_in_2023','population_growthRate']])

# %%
sns.stripplot(x=wpop['population_in_2022'],y=wpop['population_growthRate'],color='y')
# Out:
# <Axes: xlabel='population_in_2022', ylabel='population_growthRate'>

# %%
sns.stripplot(x=wpop['population_in_2023'],y=wpop['population_growthRate'],color='b', jitter=True)
# Out:
# <Axes: xlabel='population_in_2023', ylabel='population_growthRate'>

# %%
sns.barplot(x=wpop['population_in_2023'],y=wpop['population_growthRate'],color='b')
# Out:
# <Axes: xlabel='population_in_2023', ylabel='population_growthRate'>

# %%
sns.boxplot(x=wpop['population_in_2023'],y=wpop['population_growthRate'],color='b')
# Out:
# <Axes: xlabel='population_in_2023', ylabel='population_growthRate'>

# %%
sns.countplot(wpop['population_growthRate'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.pointplot(x=wpop['population_in_2023'],y=wpop['population_growthRate'],color='g')
# Out:
# <Axes: xlabel='population_in_2023', ylabel='population_growthRate'>

# %%
sns.lmplot(x="population_in_2023",y="population_in_2022",data=wpop)
